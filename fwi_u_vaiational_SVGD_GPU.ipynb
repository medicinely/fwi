# %% [markdown]
# **main script**
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/medicinely/fwi/blob/main/testcode.ipynb">
#     <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />
#     Run in Google Colab</a>
#   </td>

# %%
# !git clone https://github.com/medicinely/fwi.git
# %cd fwi

# %% [markdown]
# # Deterministic Full Waveform Inversion

# %%
import cupy as cp

def f(x):
    return cp.log(x*2)

# Convert input data to CuPy array
x=cp.array([1,2,3])
y=cp.ndarray((3,)) 

# Define a CuPy kernel to compute y_i = f(x_i) for a single input element
kernel_code = '''
T y = long_nonlinear_function(x[i]);
'''

# Define a CuPy kernel to compute y_i = f(x_i) for a single input element
kernel = cp.ElementwiseKernel(
    'T x',  # Input argument data type
    'T y',  # Output argument data type
    'x*2',  # Kernel code
    'kernel',  # Kernel name
    # preamble='''{}'''.format(f.__code__)
)

# Launch the kernel on the GPU to compute y_gpu = f(x_gpu)
kernel(x)
# Out:
# array([1, 2, 3])

# %%
import cupy as cp
from cupy.cuda import compile_with_cache

def f(x):
    return x ** 2

kernel_code = '''
extern "C" __global__
void my_kernel(int n, float* x, float* y) {
    int i = blockIdx.x * blockDim.x + threadIdx.x;
    if (i < n) {
        y[i] = f(x[i]);
    }
}
'''

n = 1000000
block_size = 256
grid_size = (n + block_size - 1) // block_size

x = cp.arange(n, dtype=cp.float32)
y = cp.zeros(n, dtype=cp.float32)

my_kernel = compile_with_cache(kernel_code, {'f': f}, 'my_kernel')
my_kernel(grid_size, block_size, (n, x, y))

print(y)
# Out:
# c:\Users\lenovo\.conda\envs\geostat\lib\site-packages\cupy\cuda\compiler.py:464: UserWarning: cupy.cuda.compile_with_cache has been deprecated in CuPy v10, and will be removed in the future. Use cupy.RawModule or cupy.RawKernel instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 24
#      21 x = cp.arange(n, dtype=cp.float32)
#      22 y = cp.zeros(n, dtype=cp.float32)
# ---> 24 my_kernel = compile_with_cache(kernel_code, {'f': f}, 'my_kernel')
#      25 my_kernel(grid_size, block_size, (n, x, y))
#      27 print(y)
#
# File c:\Users\lenovo\.conda\envs\geostat\lib\site-packages\cupy\cuda\compiler.py:468, in compile_with_cache(*args, **kwargs)
#     462 def compile_with_cache(*args, **kwargs):
#     463     # TODO(asi1024): Remove in CuPy v13+.
#     464     warnings.warn(
#     465         'cupy.cuda.compile_with_cache has been deprecated in CuPy v10, and'
#     466         ' will be removed in the future. Use cupy.RawModule or cupy.RawKernel'
#     467         ' instead.', UserWarning)
# --> 468     return _compile_module_with_cache(*args, **kwargs)
#
# File c:\Users\lenovo\.conda\envs\geostat\lib\site-packages\cupy\cuda\compiler.py:496, in _compile_module_with_cache(source, options, arch, cache_dir, extra_source, backend, enable_cooperative_groups, name_expressions, log_stream, jitify)
#     492     return _compile_with_cache_hip(
#     493         source, options, arch, cache_dir, extra_source, backend,
#     494         name_expressions, log_stream, cache_in_memory)
#     495 else:
# --> 496     return _compile_with_cache_cuda(
#     497         source, options, arch, cache_dir, extra_source, backend,
#     498         enable_cooperative_groups, name_expressions, log_stream,
#     499         cache_in_memory, jitify)
#
# File c:\Users\lenovo\.conda\envs\geostat\lib\site-packages\cupy\cuda\compiler.py:513, in _compile_with_cache_cuda(source, options, arch, cache_dir, extra_source, backend, enable_cooperative_groups, name_expressions, log_stream, cache_in_memory, jitify)
#     510 if arch is None:
#     511     arch = _get_arch()
# --> 513 options += ('-ftz=true',)
#     515 if enable_cooperative_groups:
#     516     # `cooperative_groups` requires relocatable device code.
#     517     options += ('--device-c',)
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'tuple'

# %%
from IPython.display import clear_output
import time
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
labelsize = 16

from scipy.optimize import minimize
from func.propagation import prop2d, defmodel
from func.inversion import J,second_order_derivative
from func.velocity_model import check_model, gaussian2d

import tensorflow as tf
import tensorflow_probability as tfp
from sklearn.metrics.pairwise import pairwise_distances
# print('GPU:',tf.config.list_physical_devices('GPU'))

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# import cupy as cp
device = 'cpu'

## Tensorflow mapping function
# def f_tf(u, vmin=2000, vmax=3000):
#     cdf = tfp.distributions.Normal(loc=0, scale=1).cdf(u)
#     # cdf =  tf.math.exp(-tf.math.square(u_tf)) / tf.math.sqrt(2.0 * np.pi)
#     v = (vmax - vmin) * cdf + vmin
#     return v

# Mapping function from u to v
def f(u, vmin=2000, vmax=3000):
    # CDF of gaussian
    cdf = sc.stats.norm.cdf(u.flatten(), loc=0, scale=1)
    v = (vmax-vmin) * cdf + vmin
    return v

# def f(u, a=2000, b=3000):
# 	'''
# 	Reparametrization mapping function from u -> v
# 	Unconstrained parameter -> Physical parameter space
# 	'''
# 	v = a+(b-a)/(1+np.exp(-u))

# 	return v


def f_inv(v, a=2000, b=3000):
	'''Inverse of the mapping function f^-1'''
	u = np.log(v-a) - np.log(b-v)

	return u


# Define cost function
def loglik_fn(u,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha):
	# J: Prior part
	v = f(u)
	log_likelihood = -J(v,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device) / alpha
 
	return tf.cast(log_likelihood, tf.float32)

# Calculate gradient with Adjoint state method
def dloglik_du_fn(u,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha):
	"""
	Calculate gradiant using adjoint state method
	"""
	# Calculate forward propagated p_fwd(z,x,t) (to update)
	v = f(u)
	nz, nx, nt = len(az), len(ax), len(at)
	if v.ndim == 1: v = np.reshape(v,(nz,nx))
	p_fwd = prop2d(wsrc,zxsrc,v,at,az,ax,next, device)
	d = p_fwd[zxrec[0], zxrec[1], :]
	residual = d - d_obs # residual shape (n_rec, nt) - residual.shape=(5,801)
	# Calculate back propagated p_back(z,x,t)
	p_back = prop2d(np.flip(residual,axis=1), zxrec, v, at, az, ax, next, device)
	p_back = np.flip(p_back,axis=2)
	# Calculate second order time derivative of p_fwd(z,x,t)
	p_dt_dt = second_order_derivative(p_fwd, at, az, ax)
	# Calculate gradiant
	dJ_dv = 2/v**3  * np.sum(p_back * p_dt_dt, axis=2) # G.shape = (201,201)
	dloglik_dv = -dJ_dv / alpha
	dv_du = sc.misc.derivative(f,u)

	return tf.cast(dloglik_dv.flatten() * dv_du.flatten(), tf.float32)

def dlog_prob_du_fn(u,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha):
	"""
	Calculate gradiant using adjoint state method
	"""
	dloglik_du = dloglik_du_fn(u,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha)
	dlog_prior_du = -Q.dot(u.flatten())

	return dloglik_du + dlog_prior_du

# %% [markdown]
# ## Forward modeling

# %%
# Model size (nz,nx) = (29,29)
import pickle
# load data
filename = './data/u_29'
infile = open(filename, 'rb')
u_ref = pickle.load(infile)
infile.close()

filename = './data/Q_29'
infile = open(filename, 'rb')
Q = pickle.load(infile)
infile.close()

# Initialize the model axis az, ax, at
nz,nx,nt = 29,29,235
vmin,vmax=2000,3000
izsrc, ixsrc = [1], [nx//2]
next = 10

# v_ref = gaussian2d(ranges=[20,5],variance=50,nx=[nz,nx],param=1,mean=2500)
# u_ref, Q = gaussian2d(ranges = [20,5],param=1,nx=[nz,nx],variance=1,mean=0)
u_ref = u_ref.flatten()
v_ref = f(u_ref)

az, ax, at, next, wsrc, zxsrc = defmodel(
                      vmin=vmin, vmax=vmax, fmax=25, # key parameters
                      nz=nz, nx=nx, nt=nt, # number of indices
                      izsrc=izsrc, ixsrc=ixsrc,  # define source coordinates z, x
                      ext=next)  

# check_model(v=v_ref, vmin=vmin, vmax=vmax)
# Set receiver z and x coordinates
interv = 1 # interval between receivers
receivers_width = np.append(np.arange(zxsrc[1][0],0,-interv)[::-1][:-1], #left
							np.arange(zxsrc[1][0],nx-1,interv)) #right
nrec = len(receivers_width)
# zxrec = np.vstack((np.full(nrec, zxsrc[0]), receivers_width)) # Top
zxrec1 = np.vstack((np.full(nrec, zxsrc[0]), receivers_width)) # Top
zxrec2 = np.vstack((np.full(nrec, nz-zxsrc[0]-1), receivers_width)) # Bottom
zxrec3 = np.vstack((receivers_width, np.full(nrec, zxsrc[0]))) # Left
zxrec4 = np.vstack((receivers_width, np.full(nrec, nz-zxsrc[0]-1))) # Right
zxrec = np.hstack((zxrec1,zxrec2,zxrec3,zxrec4))
zxrec = zxrec1
zxrec = np.unique(zxrec,axis=1)
print("Number of receivers:", len(zxrec.flatten())//2)
# d_obs = simulate_obs(f(u_ref).resh, wsrc, zxsrc, at, az, ax, next, zxrec)
p = prop2d(wsrc,zxsrc,v_ref.reshape(nz,nx),at,az,ax,next,device)
d_obs = p[zxrec[0], zxrec[1], :]

plt.figure(figsize=(8,3))
plt.subplot(1,2,1) 
plt.imshow(v_ref.reshape((nz,nx)),vmin=2000,vmax=3000)
plt.colorbar()
plt.scatter(zxsrc[1,:],zxsrc[0,:],marker='*',color='r',s=300,alpha=0.6,label="Source")
plt.scatter(zxrec[1,:],zxrec[0,:],marker='s',color='w',s=5,alpha=0.8,label="Receivers")
plt.legend(loc='lower right')
plt.title("$V_{true}$")
plt.subplot(1,2,2)
plt.imshow(d_obs.T,cmap='bwr',vmin=-10,vmax=10,extent=[at[0], at[-1], az[-1], az[0]], aspect='auto')
plt.title("Observation $d_{obs}$")
plt.show()
# Out:
# dz,dx,dt (m): 8.0 8.0 0.001697056274847714
# Model dimension [nz,nx,nt]:  29 29 235
# Number of receivers: 27

# %% [markdown]
# ## Inversion with prior regularization term

# %%
# Define cost function
def objective_fwi_prior(u,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha):
	# J: Prior part
	v = f(u)
	loss_J = J(v,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device) / alpha
	print("Loss (J) = %.4f " % loss_J, end='')
	# Q: Likelihood part
	u = u.flatten()
	penalty = .5 * u.T.dot(Q.toarray()).dot(u)
	print("Penalty term = %.4f " % penalty, end='')
	# Total loss
	loss = loss_J + penalty
	print("Total loss = %.4f " % loss)
	# Save history
	global current_loss
	current_loss = np.array([loss,loss_J,penalty])

	return loss

# Calculate gradient with Adjoint state method
def gradiant_fwi_prior(u,d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha):
	"""
	Calculate gradiant using adjoint state method
	"""
	# Calculate forward propagated p_fwd(z,x,t) (to update)
	v = f(u)
	nz, nx, nt = len(az), len(ax), len(at)
	if v.ndim == 1: v = np.reshape(v,(nz,nx))
	p_fwd = prop2d(wsrc,zxsrc,v,at,az,ax,next, device)
	receiver_depth = zxrec[0]
	d = p_fwd[zxrec[0], zxrec[1], :]
	residual = d - d_obs # residual shape (n_rec, nt) - residual.shape=(5,801)
	# Calculate back propagated p_back(z,x,t)
	p_back = prop2d(np.flip(residual,axis=1), zxrec, v, at, az, ax, next, device)
	p_back = np.flip(p_back,axis=2)
	# Calculate second order time derivative of p_fwd(z,x,t)
	p_dt_dt = second_order_derivative(p_fwd, at, az, ax)
	# Calculate gradiant
	G = 2/v**3  * np.sum(p_back * p_dt_dt, axis=2) # G.shape = (201,201)

	return G.flatten()*sc.misc.derivative(f,u).flatten()/ alpha + Q.dot(u.flatten())

# Record loss history over each iterations
def callback(xk):
	global loss_tracker
	loss_tracker = np.vstack([loss_tracker,current_loss])
	
# minimize cost function
start = time.time()
u_init = np.zeros([nz*nx])   # Set initial velocity guess (u=0 -> v=2500)
v_init = f(u_init)   # Initial v
loss_tracker = np.empty((0,3))

std_noise = 0.1 # define the noise level
alpha = std_noise**2 # Regularization parameter/weight (Variance of observation noise)

resi = minimize(fun = objective_fwi_prior, 
               x0 = u_init, 
               args = (d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device,alpha),
               method='L-BFGS-B', 
               # method='Newton-CG',
            #    bounds = np.full((len(u_init.flatten()), 2), (vmin,vmax)),
               jac = gradiant_fwi_prior,
               options = {'disp':True, 'maxiter':150},
               callback=callback
              )
u_fwi = resi.x
print(u_fwi.shape)
print('Total time',time.strftime("%Hh %Mm %Ss", time.gmtime(time.time()-start)))
# Out:
# Loss (J) = 199535.0765 Penalty term = 0.0000 Total loss = 199535.0765
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9224\4234860350.py:41: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   return G.flatten()*sc.misc.derivative(f,u).flatten()/ alpha + Q.dot(u.flatten())
# Loss (J) = 159558.7027 Penalty term = 0.2699 Total loss = 159558.9726
# Loss (J) = 52147.5700 Penalty term = 6.7470 Total loss = 52154.3170
# Loss (J) = 17960.6003 Penalty term = 14.0674 Total loss = 17974.6677
# Loss (J) = 11494.9893 Penalty term = 12.4578 Total loss = 11507.4471
# Loss (J) = 4072.0373 Penalty term = 9.7125 Total loss = 4081.7498
# Loss (J) = 2384.6590 Penalty term = 8.8628 Total loss = 2393.5218
# Loss (J) = 1726.4252 Penalty term = 10.1514 Total loss = 1736.5766
# Loss (J) = 1383.6978 Penalty term = 10.9817 Total loss = 1394.6795
# Loss (J) = 980.3566 Penalty term = 12.4077 Total loss = 992.7643
# Loss (J) = 758.5020 Penalty term = 12.8223 Total loss = 771.3243
# Loss (J) = 692.1097 Penalty term = 11.7444 Total loss = 703.8540
# Loss (J) = 625.0038 Penalty term = 10.2030 Total loss = 635.2067
# Loss (J) = 560.0131 Penalty term = 9.8739 Total loss = 569.8870
# Loss (J) = 441.7715 Penalty term = 9.3760 Total loss = 451.1475
# Loss (J) = 399.4580 Penalty term = 9.2138 Total loss = 408.6718
# Loss (J) = 350.3690 Penalty term = 9.2757 Total loss = 359.6447
# Loss (J) = 355.1541 Penalty term = 9.3577 Total loss = 364.5118
# Loss (J) = 347.1494 Penalty term = 9.2449 Total loss = 356.3943
# Loss (J) = 353.8885 Penalty term = 9.1597 Total loss = 363.0483
# Loss (J) = 343.2389 Penalty term = 9.1630 Total loss = 352.4019
# Loss (J) = 354.5330 Penalty term = 9.0283 Total loss = 363.5613
# Loss (J) = 339.6746 Penalty term = 9.0602 Total loss = 348.7347
# Loss (J) = 346.8402 Penalty term = 8.8364 Total loss = 355.6766
# Loss (J) = 338.3068 Penalty term = 8.9616 Total loss = 347.2684
# Loss (J) = 349.5386 Penalty term = 8.8161 Total loss = 358.3547
# Loss (J) = 336.8943 Penalty term = 8.8556 Total loss = 345.7498
# Loss (J) = 356.1717 Penalty term = 9.1474 Total loss = 365.3191
# Loss (J) = 335.8190 Penalty term = 8.7519 Total loss = 344.5709
# Loss (J) = 341.9099 Penalty term = 9.1241 Total loss = 351.0340
# Loss (J) = 334.2017 Penalty term = 8.6952 Total loss = 342.8969
# Loss (J) = 366.7156 Penalty term = 10.9340 Total loss = 377.6496
# Loss (J) = 332.9314 Penalty term = 8.7347 Total loss = 341.6661
# Loss (J) = 356.4419 Penalty term = 11.9467 Total loss = 368.3886
# Loss (J) = 331.1207 Penalty term = 8.9209 Total loss = 340.0416
# Loss (J) = 362.8607 Penalty term = 11.8628 Total loss = 374.7235
# Loss (J) = 330.5144 Penalty term = 9.1105 Total loss = 339.6249
# Loss (J) = 344.6153 Penalty term = 10.6493 Total loss = 355.2646
# Loss (J) = 330.7598 Penalty term = 9.2468 Total loss = 340.0066
# Loss (J) = 592.0571 Penalty term = 30.6100 Total loss = 622.6670
# Loss (J) = 331.4716 Penalty term = 9.7346 Total loss = 341.2062
# Loss (J) = 330.7135 Penalty term = 9.3271 Total loss = 340.0406
# Loss (J) = 330.7433 Penalty term = 9.2630 Total loss = 340.0063
# Loss (J) = 330.7560 Penalty term = 9.2502 Total loss = 340.0062
# Loss (J) = 330.7474 Penalty term = 9.2587 Total loss = 340.0060
# Loss (J) = 330.7447 Penalty term = 9.2615 Total loss = 340.0062
# Loss (J) = 330.7468 Penalty term = 9.2593 Total loss = 340.0061
# Loss (J) = 330.7474 Penalty term = 9.2587 Total loss = 340.0060
# Loss (J) = 447.1199 Penalty term = 23.9751 Total loss = 471.0951
# Loss (J) = 329.6970 Penalty term = 9.9648 Total loss = 339.6618
# Loss (J) = 607.9484 Penalty term = 18.3993 Total loss = 626.3477
# Loss (J) = 329.7513 Penalty term = 10.2748 Total loss = 340.0261
# Loss (J) = 329.4825 Penalty term = 10.0290 Total loss = 339.5115
# Loss (J) = 329.4767 Penalty term = 10.1887 Total loss = 339.6654
# Loss (J) = 329.4225 Penalty term = 10.0616 Total loss = 339.4841
# Loss (J) = 329.4084 Penalty term = 10.1448 Total loss = 339.5532
# Loss (J) = 405.5933 Penalty term = 20.0395 Total loss = 425.6328
# Loss (J) = 329.6123 Penalty term = 10.7802 Total loss = 340.3925
# Loss (J) = 329.2885 Penalty term = 10.2611 Total loss = 339.5496
# Loss (J) = 329.3563 Penalty term = 10.5950 Total loss = 339.9512
# Loss (J) = 329.2573 Penalty term = 10.3238 Total loss = 339.5810
# Loss (J) = 329.2804 Penalty term = 10.2737 Total loss = 339.5541
# Loss (J) = 329.2885 Penalty term = 10.2611 Total loss = 339.5496
# Loss (J) = 388.7637 Penalty term = 21.4038 Total loss = 410.1675
# Loss (J) = 327.6513 Penalty term = 11.2608 Total loss = 338.9121
# Loss (J) = 607.4576 Penalty term = 19.8927 Total loss = 627.3503
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 1843.1416 Penalty term = 63.7681 Total loss = 1906.9096
# Loss (J) = 327.9671 Penalty term = 12.0545 Total loss = 340.0216
# Loss (J) = 327.1972 Penalty term = 11.6078 Total loss = 338.8051
# Loss (J) = 327.1925 Penalty term = 11.5355 Total loss = 338.7280
# Loss (J) = 327.1958 Penalty term = 11.5217 Total loss = 338.7174
# Loss (J) = 327.1966 Penalty term = 11.5189 Total loss = 338.7155
# Loss (J) = 327.1967 Penalty term = 11.5184 Total loss = 338.7151
# Loss (J) = 327.1968 Penalty term = 11.5183 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5183 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 327.1968 Penalty term = 11.5182 Total loss = 338.7150
# Loss (J) = 185470.6047 Penalty term = 14873.4371 Total loss = 200344.0418
# Loss (J) = 1725.9694 Penalty term = 11.8296 Total loss = 1737.7989
# Loss (J) = 318.5226 Penalty term = 11.4481 Total loss = 329.9707
# Loss (J) = 310.9922 Penalty term = 11.3117 Total loss = 322.3039
# Loss (J) = 295.4382 Penalty term = 10.9626 Total loss = 306.4008
# Loss (J) = 282.0449 Penalty term = 10.5871 Total loss = 292.6320
# Loss (J) = 274.5682 Penalty term = 10.4548 Total loss = 285.0230
# Loss (J) = 270.5806 Penalty term = 10.3198 Total loss = 280.9004
# Loss (J) = 263.8683 Penalty term = 10.1414 Total loss = 274.0097
# Loss (J) = 254.3960 Penalty term = 10.2084 Total loss = 264.6043
# Loss (J) = 237.5269 Penalty term = 11.1265 Total loss = 248.6534
# Loss (J) = 223.3614 Penalty term = 12.2591 Total loss = 235.6205
# Loss (J) = 209.5851 Penalty term = 12.4857 Total loss = 222.0708
# Loss (J) = 209.0868 Penalty term = 11.3098 Total loss = 220.3965
# Loss (J) = 208.5534 Penalty term = 10.8291 Total loss = 219.3826
# Loss (J) = 196.2885 Penalty term = 11.5944 Total loss = 207.8829
# Loss (J) = 185.0991 Penalty term = 14.3425 Total loss = 199.4416
# Loss (J) = 173.5217 Penalty term = 15.6244 Total loss = 189.1461
# Loss (J) = 158.7433 Penalty term = 15.7294 Total loss = 174.4727
# Loss (J) = 157.7008 Penalty term = 13.8929 Total loss = 171.5936
# Loss (J) = 165.4145 Penalty term = 11.8041 Total loss = 177.2186
# Loss (J) = 157.1341 Penalty term = 13.3637 Total loss = 170.4979
# Loss (J) = 160.7809 Penalty term = 12.1278 Total loss = 172.9088
# Loss (J) = 155.8505 Penalty term = 12.8972 Total loss = 168.7477
# Loss (J) = 153.5528 Penalty term = 12.7615 Total loss = 166.3143
# Loss (J) = 149.5640 Penalty term = 13.2929 Total loss = 162.8569
# Loss (J) = 145.5733 Penalty term = 15.9395 Total loss = 161.5128
# Loss (J) = 133.3715 Penalty term = 16.8272 Total loss = 150.1987
# Loss (J) = 135.2259 Penalty term = 14.8513 Total loss = 150.0772
# Loss (J) = 131.7909 Penalty term = 14.6812 Total loss = 146.4721
# Loss (J) = 129.7968 Penalty term = 15.2361 Total loss = 145.0329
# Loss (J) = 128.5162 Penalty term = 15.5502 Total loss = 144.0664
# Loss (J) = 125.9921 Penalty term = 19.2880 Total loss = 145.2801
# Loss (J) = 124.3236 Penalty term = 16.3212 Total loss = 140.6448
# Loss (J) = 166.9426 Penalty term = 31.7718 Total loss = 198.7144
# Loss (J) = 117.7149 Penalty term = 18.2057 Total loss = 135.9206
# Loss (J) = 119.8988 Penalty term = 19.1863 Total loss = 139.0851
# Loss (J) = 115.0508 Penalty term = 18.4539 Total loss = 133.5047
# Loss (J) = 110.5859 Penalty term = 19.0134 Total loss = 129.5994
# Loss (J) = 105.0835 Penalty term = 20.8794 Total loss = 125.9629
# Loss (J) = 98.0943 Penalty term = 20.0843 Total loss = 118.1786
# Loss (J) = 90.3764 Penalty term = 18.0259 Total loss = 108.4023
# Loss (J) = 92.3258 Penalty term = 18.2493 Total loss = 110.5751
# Loss (J) = 87.7713 Penalty term = 18.0751 Total loss = 105.8464
# Loss (J) = 84.6781 Penalty term = 18.9898 Total loss = 103.6679
# Loss (J) = 80.7182 Penalty term = 20.6020 Total loss = 101.3203
# Loss (J) = 75.9103 Penalty term = 20.7824 Total loss = 96.6926
# Loss (J) = 72.5628 Penalty term = 19.5304 Total loss = 92.0933
# Loss (J) = 71.1321 Penalty term = 19.1721 Total loss = 90.3042
# Loss (J) = 70.2201 Penalty term = 19.7709 Total loss = 89.9910
# Loss (J) = 65.6695 Penalty term = 19.9393 Total loss = 85.6088
# Loss (J) = 60.5811 Penalty term = 20.5747 Total loss = 81.1558
# Loss (J) = 53.9355 Penalty term = 21.7619 Total loss = 75.6974
# Loss (J) = 50.6480 Penalty term = 22.3580 Total loss = 73.0060
# Loss (J) = 46.7250 Penalty term = 23.6600 Total loss = 70.3850
# Loss (J) = 50.7878 Penalty term = 28.6440 Total loss = 79.4318
# Loss (J) = 45.7552 Penalty term = 24.1810 Total loss = 69.9362
# Loss (J) = 46.1949 Penalty term = 25.0642 Total loss = 71.2591
# Loss (J) = 43.8276 Penalty term = 24.1902 Total loss = 68.0177
# Loss (J) = 40.5442 Penalty term = 22.6278 Total loss = 63.1720
# Loss (J) = 43.1328 Penalty term = 17.8911 Total loss = 61.0239
# Loss (J) = 39.6102 Penalty term = 20.0116 Total loss = 59.6217
# Loss (J) = 37.5391 Penalty term = 18.2217 Total loss = 55.7608
# Loss (J) = 42.7515 Penalty term = 15.5937 Total loss = 58.3452
# Loss (J) = 37.2972 Penalty term = 17.2776 Total loss = 54.5748
# Loss (J) = 37.4973 Penalty term = 16.5405 Total loss = 54.0378
# Loss (J) = 35.3412 Penalty term = 16.5435 Total loss = 51.8847
# Loss (J) = 31.4993 Penalty term = 16.2818 Total loss = 47.7811
# Loss (J) = 38.4468 Penalty term = 18.0391 Total loss = 56.4859
# Loss (J) = 29.1222 Penalty term = 15.9371 Total loss = 45.0593
# Loss (J) = 31.6305 Penalty term = 14.9990 Total loss = 46.6294
# Loss (J) = 28.5336 Penalty term = 15.6342 Total loss = 44.1678
# Loss (J) = 30.9364 Penalty term = 14.3680 Total loss = 45.3044
# Loss (J) = 28.5456 Penalty term = 15.3598 Total loss = 43.9054
# Loss (J) = 34.5459 Penalty term = 13.5505 Total loss = 48.0964
# Loss (J) = 28.6411 Penalty term = 14.9792 Total loss = 43.6203
# Loss (J) = 32.6002 Penalty term = 13.3945 Total loss = 45.9947
# Loss (J) = 28.7523 Penalty term = 14.5699 Total loss = 43.3222
# Loss (J) = 30.4860 Penalty term = 13.2931 Total loss = 43.7791
# Loss (J) = 28.7708 Penalty term = 14.1293 Total loss = 42.9001
# Loss (J) = 32.9813 Penalty term = 12.8036 Total loss = 45.7848
# Loss (J) = 28.7897 Penalty term = 13.7819 Total loss = 42.5716
# Loss (J) = 28.4312 Penalty term = 12.7318 Total loss = 41.1630
# Loss (J) = 27.7519 Penalty term = 12.4511 Total loss = 40.2030
# Loss (J) = 26.5914 Penalty term = 11.7139 Total loss = 38.3052
# Loss (J) = 28.6544 Penalty term = 11.6535 Total loss = 40.3080
# Loss (J) = 26.5854 Penalty term = 11.6696 Total loss = 38.2550
# Loss (J) = 27.5321 Penalty term = 11.6003 Total loss = 39.1324
# Loss (J) = 26.6169 Penalty term = 11.6480 Total loss = 38.2649
# Loss (J) = 37.8698 Penalty term = 12.7821 Total loss = 50.6519
# Loss (J) = 26.5839 Penalty term = 11.5655 Total loss = 38.1494
# Loss (J) = 36.9216 Penalty term = 10.7564 Total loss = 47.6780
# Loss (J) = 26.4169 Penalty term = 11.4724 Total loss = 37.8893
# Loss (J) = 132.7373 Penalty term = 14.4524 Total loss = 147.1897
# Loss (J) = 26.5002 Penalty term = 11.3479 Total loss = 37.8481
# Loss (J) = 40.4777 Penalty term = 10.9767 Total loss = 51.4543
# Loss (J) = 26.6746 Penalty term = 11.2845 Total loss = 37.9591
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 64.6160 Penalty term = 12.1445 Total loss = 76.7606
# Loss (J) = 26.7916 Penalty term = 11.2308 Total loss = 38.0223
# Loss (J) = 26.5496 Penalty term = 11.3184 Total loss = 37.8680
# Loss (J) = 26.5259 Penalty term = 11.3341 Total loss = 37.8600
# Loss (J) = 26.5219 Penalty term = 11.3371 Total loss = 37.8590
# Loss (J) = 26.5211 Penalty term = 11.3378 Total loss = 37.8589
# Loss (J) = 26.5210 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 26.5209 Penalty term = 11.3379 Total loss = 37.8588
# Loss (J) = 658292.3231 Penalty term = 1286.2309 Total loss = 659578.5540
# Loss (J) = 25.4246 Penalty term = 11.3057 Total loss = 36.7302
# Loss (J) = 24.4853 Penalty term = 11.2978 Total loss = 35.7831
# Loss (J) = 24.1978 Penalty term = 11.2773 Total loss = 35.4751
# Loss (J) = 24.0660 Penalty term = 11.2247 Total loss = 35.2907
# Loss (J) = 24.1222 Penalty term = 11.1473 Total loss = 35.2696
# Loss (J) = 24.1456 Penalty term = 10.9850 Total loss = 35.1306
# Loss (J) = 24.5357 Penalty term = 10.7213 Total loss = 35.2570
# Loss (J) = 24.0722 Penalty term = 10.9025 Total loss = 34.9747
# Loss (J) = 24.1404 Penalty term = 10.5617 Total loss = 34.7021
# Loss (J) = 23.8707 Penalty term = 10.4825 Total loss = 34.3532
# Loss (J) = 23.0914 Penalty term = 10.4639 Total loss = 33.5552
# Loss (J) = 22.7662 Penalty term = 10.4640 Total loss = 33.2303
# Loss (J) = 22.6872 Penalty term = 10.4396 Total loss = 33.1268
# Loss (J) = 23.5473 Penalty term = 10.2526 Total loss = 33.7998
# Loss (J) = 22.6904 Penalty term = 10.4094 Total loss = 33.0998
# Loss (J) = 24.2009 Penalty term = 10.1715 Total loss = 34.3724
# Loss (J) = 22.7354 Penalty term = 10.3781 Total loss = 33.1135
# Loss (J) = 22.6969 Penalty term = 10.4033 Total loss = 33.1002
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6951 Penalty term = 10.4049 Total loss = 33.1000
# Loss (J) = 22.6924 Penalty term = 10.4075 Total loss = 33.0998
# Loss (J) = 22.6918 Penalty term = 10.4080 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 24.9886 Penalty term = 10.1040 Total loss = 35.0926
# Loss (J) = 22.7544 Penalty term = 10.3657 Total loss = 33.1201
# Loss (J) = 22.7007 Penalty term = 10.3999 Total loss = 33.1006
# Loss (J) = 22.6934 Penalty term = 10.4064 Total loss = 33.0999
# Loss (J) = 22.6921 Penalty term = 10.4078 Total loss = 33.0998
# Loss (J) = 22.6918 Penalty term = 10.4080 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 22.6917 Penalty term = 10.4081 Total loss = 33.0998
# Loss (J) = 160959.8857 Penalty term = 198.2227 Total loss = 161158.1084
# Loss (J) = 22.6654 Penalty term = 10.4029 Total loss = 33.0682
# Loss (J) = 22.6628 Penalty term = 10.3794 Total loss = 33.0422
# Loss (J) = 22.7053 Penalty term = 10.3489 Total loss = 33.0542
# Loss (J) = 22.6641 Penalty term = 10.3724 Total loss = 33.0365
# Loss (J) = 22.8462 Penalty term = 10.2618 Total loss = 33.1080
# Loss (J) = 22.6521 Penalty term = 10.3434 Total loss = 32.9955
# Loss (J) = 23.7812 Penalty term = 10.1367 Total loss = 33.9179
# Loss (J) = 22.6725 Penalty term = 10.3125 Total loss = 32.9850
# Loss (J) = 23.7048 Penalty term = 10.0957 Total loss = 33.8005
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 24.3369 Penalty term = 9.9951 Total loss = 34.3320
# Loss (J) = 22.7579 Penalty term = 10.2366 Total loss = 32.9945
# Loss (J) = 22.7063 Penalty term = 10.2684 Total loss = 32.9747
# Loss (J) = 22.6991 Penalty term = 10.2743 Total loss = 32.9734
# Loss (J) = 22.6977 Penalty term = 10.2754 Total loss = 32.9732
# Loss (J) = 22.6975 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# Loss (J) = 22.6974 Penalty term = 10.2757 Total loss = 32.9731
# (841,)
# Total time 00h 01m 20s

# %% [markdown]
# ## FWI result

# %%
# Plot deterministic FWI result and optimization history
v_fwi = f(u_fwi)

plt.figure(figsize=(10,8),dpi=80)
plt.suptitle("$\sigma_{Noise}$ = %.2f  " % std_noise,fontsize=labelsize+8)
# plt.suptitle("$Loss$ = %.2f " % loss_tracker[-1,0],fontsize=labelsize)
plt.subplot(2,2,1) 
plt.imshow(v_ref.reshape(nz,nx),vmin=2000,vmax=3000,extent=[ax[0],ax[-1],az[-1],az[0]], aspect='equal')
cbar = plt.colorbar()
cbar.set_label("Velocity (m/s)")
plt.xlabel('Distance (m)', fontsize=labelsize)
plt.ylabel('Depth (m)', fontsize=labelsize)
plt.title("$V_{True}$",fontsize=labelsize+4)
plt.subplot(2,2,2) 
plt.imshow(v_init.reshape(nz,nx),vmin=2000,vmax=3000,extent=[ax[0],ax[-1],az[-1],az[0]], aspect='equal')
cbar = plt.colorbar()
cbar.set_label("Velocity (m/s)")
plt.xlabel('Distance (m)', fontsize=labelsize)
plt.ylabel('Depth (m)', fontsize=labelsize)
plt.title("$V_{Initial\ Guess}$",fontsize=labelsize+4)
plt.subplot(2,2,3)
plt.imshow(v_fwi.reshape(nz,nx),vmin=2000,vmax=3000,extent=[ax[0],ax[-1],az[-1],az[0]], aspect='equal')
cbar = plt.colorbar()
cbar.set_label("Velocity (m/s)")
plt.xlabel('Distance (m)', fontsize=labelsize)
plt.ylabel('Depth (m)', fontsize=labelsize)
# plt.scatter(zxsrc[1,:],zxsrc[0,:],marker='*',color='r',s=100,alpha=0.6,label="Source")
# plt.scatter(zxrec[1,:],zxrec[0,:],marker='s',color='w',s=0.1,alpha=0.8,label="Receivers")
# plt.legend(loc='lower right')
# plt.title("$V_{Inversion}$ with $\sigma_{Noise}$ = %.2f " % std_noise)
plt.title("$V_{Inversion}$",fontsize=labelsize+4)
plt.subplot(2,2,4)
plt.title("Final cost = %.2f " % loss_tracker[-1,0],fontsize=labelsize)
plt.plot(loss_tracker[:,1],label="Data misfit")
plt.plot(loss_tracker[:,2],label="Regularization penalty")
plt.plot(loss_tracker[:,0],label="Total cost")
plt.xlabel("Iteration",fontsize=labelsize)
plt.ylabel("Cost",fontsize=labelsize)
# plt.xlim(0,150)
# plt.ylim(0,800)
plt.legend(fontsize=labelsize-4)
plt.tight_layout()
plt.show()

# %% [markdown]
# # SVGD

# %%
import multiprocessing

def compute_loglik_fn(u):
    # your implementation of loglik_fn here
    return loglik_fn(u.numpy(),d_obs,*args)
    # return -0

def compute_dloglik_du_fn(u):
    # your implementation of dloglik_du_fn here
    return dloglik_du_fn(u.numpy(),d_obs,*args)

def compute_parallel(u_samples, num_processes=4):
    with multiprocessing.Pool(processes=num_processes) as pool:
        log_likelihoods = pool.map(compute_loglik_fn, u_samples)
        grads_log_likelihoods = pool.map(compute_dloglik_du_fn, u_samples)
    return log_likelihoods, grads_log_likelihoods

args = (wsrc,zxsrc,zxrec,at,az,ax,next,device,std_noise)

# Define the prior distribution for the model parameters
prior_mean = tf.zeros(nz*nx, dtype=tf.float32)
prior_cov = tf.cast(sc.sparse.linalg.inv(Q).toarray(), tf.float32)
prior_scale_tril = tf.cast(tf.linalg.cholesky(prior_cov), tf.float32)
p_dist = tfp.distributions.MultivariateNormalTriL(loc=prior_mean, scale_tril=prior_scale_tril)
prior_scale = p_dist.stddev()

# Define the TensorFlow variables for the variational posterior particles
num_particles = 16
N = tf.cast(num_particles, dtype=tf.float32)
q_particles_init = tf.random.normal(shape=(num_particles, nz*nx), dtype=tf.float32)
q_particles = tf.Variable(q_particles_init, dtype=tf.float32)

# Set up lists to store progress
neg_loglik_history = []
kl_history = []
misfit_history = []

optimizer = tf.keras.optimizers.Adam()

# %%
optimizer.learning_rate = 0.1

# Set hyper-parameters
std_noise = 0.1
print(f"Learning Rate: {optimizer.learning_rate.numpy()}")

# Train the variational posterior using the ELBO objective
num_iters = 5
alpha = 5  # learning rate for updating the particles

for i in range(num_iters):
  # Print the iteration number
  print(f"Iteration {i + 1}/{num_iters}", end="    ")

  with tf.GradientTape() as tape:
    # Watch the parameters of the variational posterior
    tape.watch(q_particles)
    
    ## Compute the SVGD kernel matrix and its gradient
    with tf.GradientTape() as tape2:
      rbf_kernel = tfp.math.psd_kernels.ExponentiatedQuadratic(length_scale=1.0)
      svgd_kernel_matrix = rbf_kernel.matrix(q_particles, q_particles)
      grads_kernal_matrix = tape2.gradient(svgd_kernel_matrix, q_particles)

    q_mean = tf.reduce_mean(q_particles, axis=0)
    q_cov = tfp.stats.covariance(q_particles) + 1e-5 * tf.eye(nz*nx, dtype=tf.float32)
    # if tf.linalg.det(q_cov)==0: print(" * Warning: Numerically Unstable    det(q_cov)=0")
    q_dist = tfp.distributions.MultivariateNormalTriL(q_mean, tf.linalg.cholesky(q_cov))
    misfit = J(f(q_mean.numpy()),d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device)
    
    print("J = %.2f" % misfit)
    misfit_history.append(misfit)

    # Compute the log(d_obs|v) log-likelihood and its gradient
    log_likelihoods = []
    grads_log_likelihoods = []

    # Calculate the gradient of the log-likelihoods
    log_likelihoods, grads_log_likelihoods = compute_parallel(q_particles, num_processes=8)
    # for u in q_particles:
    #   log_likelihoods.append(loglik_fn(u.numpy(), d_obs, *args))
    #   grads_log_likelihoods.append(dloglik_du_fn(u.numpy(), d_obs, *args))

    # Compute E[log likelihood] and its gradient
    # E_log_likelihoods = tf.cast(tf.reduce_mean(log_likelihoods), dtype=tf.float32)
    # grads_E_log_likelihoods = tf.cast(tf.reduce_mean(grads_log_likelihoods, axis=0), dtype=tf.float32)

    # Compute the KL(q||p) term 
    kl_divergence_q_p = tfp.distributions.kl_divergence(q_dist, p_dist)
    grads_kl_divergence_q_p = tape.gradient(kl_divergence_q_p, q_particles)
    
    # Compute the SVGD update for each particle
    # svgd_update = tf.matmul(svgd_kernel_matrix, grads_log_likelihoods) / N  - grads_kl_divergence_q_p
    grads_svgd = -tf.matmul(svgd_kernel_matrix, grads_log_likelihoods) / N  \
                  + grads_kl_divergence_q_p  \
                  + grads_kernal_matrix / N

    # Apply the SVGD update to the particles
    # q_particles = q_particles + alpha * svgd_update
    optimizer.apply_gradients(zip([grads_svgd], [q_particles]))

    # Clip the particle positions to avoid NaNs
    # q_particles = tf.clip_by_value(q_particles, -1e4, 1e4)
# Out:
# Learning Rate: 0.10000000149011612
# Iteration 1/5    J = 2108.36

# %% [markdown]
# # SVGD - Prob

# %%
import multiprocessing

def compute_dlog_prob_du_fn(u):
    # your implementation of dloglik_du_fn here
    return dlog_prob_du_fn(u.numpy(),d_obs,*args)
    # return tf.cast(gradiant_fwi_prior(u.numpy(),d_obs,*args), tf.float32)

def compute_parallel(u_samples, num_processes=4):
    with multiprocessing.Pool(processes=num_processes) as pool:
        grads_log_prob = pool.map(compute_dlog_prob_du_fn, u_samples)
    return grads_log_prob

# Define the TensorFlow variables for the variational posterior particles
num_particles = 841
N = tf.cast(num_particles, dtype=tf.float32)

# Sample from the prior distribution with precision matrix Q to initialize particles
p_mean = tf.zeros(nz*nx, dtype=tf.float32)
# p_mean = tf.convert_to_tensor(u_fwi, dtype=tf.float32)
p_cov = tf.cast(sc.sparse.linalg.inv(Q).toarray(), tf.float32)
p_dist = tfp.distributions.MultivariateNormalTriL(loc=p_mean, scale_tril=tf.linalg.cholesky(p_cov))
q_particles = tf.Variable(p_dist.sample(num_particles), dtype=tf.float32)

# Set up lists to store progress
misfit_history = []

# optimizer = tf.keras.optimizers.Adam()
optimizer = tf.optimizers.Adagrad()

del(p_cov)

# %%
# ===============================================================================================
# Set hyper-parameters
optimizer.learning_rate = 0.1
std_noise = 0.1
args = (wsrc,zxsrc,zxrec,at,az,ax,next,device,std_noise)
print(f"Learning Rate: {optimizer.learning_rate.numpy()}")

# Train the variational posterior using the ELBO objective
num_iters = 1000

for i in range(num_iters):
  # Print the iteration number
  print(f"Iteration {i + 1}/{num_iters}", end="    ")

  with tf.GradientTape() as tape:
    # Watch the parameters of the variational posterior
    tape.watch(q_particles)
  
    ## Compute the SVGD kernel matrix and its gradient  Cost: O(n^2)
    with tf.GradientTape() as tape2:
      # Compute pairwise distances between all the current particles
      med = np.median(pairwise_distances(q_particles))
      # h = med**2/np.log(num_particles)  # Set bandwidth parameter h to be med^2 / log(n)
      h = med/np.sqrt(2*np.log(num_particles))

      rbf_kernel = tfp.math.psd_kernels.ExponentiatedQuadratic(length_scale=float(h))
      svgd_kernel_matrix = rbf_kernel.matrix(q_particles, q_particles)
      grads_kernal_matrix = tape2.gradient(svgd_kernel_matrix, q_particles)
      print(tf.reduce_sum(svgd_kernel_matrix[0,:]).numpy() - 1)

    q_mean = tf.reduce_mean(q_particles, axis=0)
    q_std = tfp.stats.stddev(q_particles)
    # print(tf.reduce_mean(q_std))
    misfit = J(f(q_mean.numpy()),d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device)
    print("J = %.2f" % misfit)
    misfit_history.append(misfit)

    # Compute the log(d_obs|v) log-likelihood and its gradient
    log_likelihoods = []
    grads_log_likelihoods = []
    
    # Calculate the gradient of the log-likelihoods
    grads_log_prob = []
    # for u in q_particles: grads_log_prob.append(compute_dlog_prob_du_fn(u))
    grads_log_prob = compute_parallel(q_particles, num_processes=8)

    # Compute the SVGD update for each particle
    update_svgd = (tf.matmul(svgd_kernel_matrix, grads_log_prob) + grads_kernal_matrix) / N
    # update_svgd = tf.convert_to_tensor(grads_log_prob)
    grads_svgd = - update_svgd
    # Apply the SVGD update to the particles
    optimizer.apply_gradients(zip([grads_svgd], [q_particles]))
    # if i==20: optimizer.learning_rate = 0.01
    
    clear_output(wait=True)

    display_particles(q_particles, q_mean, save_figure=True)
# Out:
# Iteration 373/1000    2.404109239578247
# J = 84.50

# %%
# q_mean = tf.reduce_mean(q_particles, axis=0)
def display_particles(q_particles, q_mean, save_figure=False):

  vmin, vmax = f(u_ref).min(), f(u_ref).max()

  plt.figure(figsize=(14,8), dpi=300)
  plt.suptitle("$\sigma_{Noise}=$%.2f  " % std_noise + \
              "    $N_{particles}=$"+str(num_particles)+
              "     $h=%.2f$" % h,
              fontsize=labelsize+8)

  plt.subplot(2,3,1)
  plt.imshow(f(u_ref).reshape((nz,nx)),vmin=vmin, vmax=vmax)
  plt.colorbar()
  plt.scatter(zxsrc[1,:],zxsrc[0,:],marker='*',color='r',s=300,alpha=0.6,label="Source")
  plt.scatter(zxrec[1,:],zxrec[0,:],marker='s',color='w',s=5,alpha=0.8,label="Receivers")
  plt.title("Prior sample $f(u_{True} \sim p(u))$", fontsize=16)

  plt.subplot(2,3,2)
  plt.imshow(f(q_mean.numpy()).reshape((nz,nx)),vmin=vmin, vmax=vmax)
  plt.colorbar()
  plt.title("Posterior Mean $f(\mu_{X} \sim q(u))$", fontsize=16)

  plt.subplot(2,3,3)
  plt.imshow(tf.reshape(tfp.stats.stddev(q_particles),[nz,nx]),cmap='Reds')
  plt.colorbar()
  plt.title("Posterior Uncertainties $\sigma_{q}(u)$", fontsize=16)

  plt.subplot(2,3,4)
  plt.imshow(tf.reshape(p_dist.stddev(),[nz,nx]),cmap='Reds')
  plt.colorbar()
  plt.title("Prior Uncertainties $\sigma_{p}(u)$", fontsize=16)

  plt.subplot(2,3,(5,6))
  plt.plot(misfit_history, label='Data misfit J', lw=3)
  plt.xlim(0, 500*(len(misfit_history)//500+1))
  plt.ylim(bottom=0)
  plt.title("Training history", fontsize=16)
  plt.legend(fontsize=16)

  plt.tight_layout()
  # plt.show()
  if save_figure==True:
    if f'gif_{idx:02d}' not in os.listdir('./img/SVGD/'):
      os.system(f'mkdir ./img/SVGD/gif_{idx:02d}')
    plt.savefig(f'./img/SVGD/gif_{idx:02d}/img_{i}.png', 
                  transparent = False,  
                  facecolor = 'white'
                )
  plt.show()
  plt.close()

idx = max([int(f[-2:]) for f in os.listdir('./img/SVGD/')]) + 1

display_particles(q_particles, q_mean, save_figure=False)

# %%
def generate_gif(idx):
  import os
  import imageio
  frames = []
  path = f'./img/SVGD/gif_{idx:02d}/'
  files = os.listdir(path)
  files = sorted(files)
  for file in files:
      image = imageio.v2.imread(path+file)
      print(file)
      frames.append(image)

  imageio.mimsave(path+f'SVGD_{idx:02d}.gif', # output gif
                  frames,          # array of input frames
                  fps = 5)         # optional: frames per second

generate_gif(6)
# Out:
# img_0.png
# img_1.png
# img_10.png
# img_100.png
# img_101.png
# img_102.png
# img_103.png
# img_104.png
# img_105.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb Cell 18 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a>       frames.append(image)
#      <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=12'>13</a>   imageio.mimsave(path+f'SVGD_{idx:02d}.gif', # output gif
#      <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=13'>14</a>                   frames,          # array of input frames
#      <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=14'>15</a>                   fps = 5)         # optional: frames per second
# ---> <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=16'>17</a> generate_gif(6)
#
# /home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb Cell 18 in generate_gif(idx)
#       <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a> files = sorted(files)
#       <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a> for file in files:
# ----> <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=8'>9</a>     image = imageio.v2.imread(path+file)
#      <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a>     print(file)
#      <a href='vscode-notebook-cell:/home/yxie-l/med/fwi/fwi_u_vaiational_SVGD.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a>     frames.append(image)
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/v2.py:227, in imread(uri, format, **kwargs)
#     224 imopen_args["legacy_mode"] = True
#     226 with imopen(uri, "ri", **imopen_args) as file:
# --> 227     result = file.read(index=0, **kwargs)
#     229 return result
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/core/legacy_plugin_wrapper.py:147, in LegacyPlugin.read(self, index, **kwargs)
#     144     img = np.stack([im for im in self.iter(**kwargs)])
#     145     return img
# --> 147 reader = self.legacy_get_reader(**kwargs)
#     148 return reader.get_data(index)
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/core/legacy_plugin_wrapper.py:116, in LegacyPlugin.legacy_get_reader(self, **kwargs)
#     113     return self._format.get_reader(self._request)
#     115 self._request.get_file().seek(0)
# --> 116 return self._format.get_reader(self._request)
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/core/format.py:221, in Format.get_reader(self, request)
#     217 if select_mode not in self.modes:
#     218     raise RuntimeError(
#     219         f"Format {self.name} cannot read in {request.mode.image_mode} mode"
#     220     )
# --> 221 return self.Reader(self, request)
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/core/format.py:312, in Format._BaseReaderWriter.__init__(self, format, request)
#     310 self._request = request
#     311 # Open the reader/writer
# --> 312 self._open(**self.request.kwargs.copy())
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/plugins/pillow_legacy.py:391, in PNGFormat.Reader._open(self, pilmode, as_gray, ignoregamma)
#     390 def _open(self, pilmode=None, as_gray=False, ignoregamma=True):
# --> 391     return PillowFormat.Reader._open(self, pilmode=pilmode, as_gray=as_gray)
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/plugins/pillow_legacy.py:297, in PillowFormat.Reader._open(self, pilmode, as_gray)
#     295 if self._im.palette and self._im.palette.dirty:
#     296     self._im.palette.rawmode_saved = self._im.palette.rawmode
# --> 297 pil_try_read(self._im)
#     298 # Store args
#     299 self._kwargs = dict(
#     300     as_gray=as_gray, is_gray=_palette_is_grayscale(self._im)
#     301 )
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/imageio/plugins/pillow_legacy.py:648, in pil_try_read(im)
#     645 def pil_try_read(im):
#     646     try:
#     647         # this will raise an IOError if the file is not readable
# --> 648         im.getdata()[0]
#     649     except IOError as e:
#     650         site = "http://pillow.readthedocs.io/en/latest/installation.html"
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/PIL/Image.py:1323, in Image.getdata(self, band)
#    1305 def getdata(self, band=None):
#    1306     """
#    1307     Returns the contents of this image as a sequence object
#    1308     containing pixel values.  The sequence object is flattened, so
#    (...)
#    1320     :returns: A sequence-like object.
#    1321     """
# -> 1323     self.load()
#    1324     if band is not None:
#    1325         return self.im.getband(band)
#
# File ~/anaconda3/envs/geostat/lib/python3.9/site-packages/PIL/ImageFile.py:257, in ImageFile.load(self)
#     251         raise OSError(
#     252             "image file is truncated "
#     253             f"({len(b)} bytes not processed)"
#     254         )
#     256 b = b + s
# --> 257 n, err_code = decoder.decode(b)
#     258 if n < 0:
#     259     break
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mini-batch

# %%
import multiprocessing

def compute_dlog_prob_du_fn(u):
    # your implementation of dloglik_du_fn here
    return dlog_prob_du_fn(u.numpy(),d_obs,*args)

def compute_parallel(u_samples, num_processes=4):
    with multiprocessing.Pool(processes=num_processes) as pool:
        grads_log_prob = pool.map(compute_dlog_prob_du_fn, u_samples)
    return grads_log_prob

args = (wsrc,zxsrc,zxrec,at,az,ax,next,device,std_noise)

# Define the TensorFlow variables for the variational posterior particles
num_particles = 841
N = tf.cast(num_particles, dtype=tf.float32)

# Sample from the prior distribution with precision matrix Q to initialize particles
p_mean = tf.zeros(nz*nx, dtype=tf.float32)
p_cov = tf.cast(sc.sparse.linalg.inv(Q).toarray(), tf.float32)
p_dist = tfp.distributions.MultivariateNormalTriL(loc=p_mean, scale_tril=tf.linalg.cholesky(p_cov))
q_particles_init = p_dist.sample(num_particles)
q_particles = tf.Variable(q_particles_init, dtype=tf.float32)

# Set up lists to store progress
misfit_history = []

optimizer = tf.keras.optimizers.Adam()
optimizer.learning_rate = 0.1

# ===============================================================================================
# Set hyper-parameters
std_noise = 0.1
batch_size = 64  # number of particles in each mini-batch
num_batches = num_particles // batch_size  # number of mini-batches

print(f"Learning Rate: {optimizer.learning_rate.numpy()}")

# Train the variational posterior using the ELBO objective
num_iters = 50
alpha = 5  # learning rate for updating the particles

for i in range(num_iters):
  # Print the iteration number
  print(f"Iteration {i + 1}/{num_iters}", end="    ")

  with tf.GradientTape() as tape:
    # Watch the parameters of the variational posterior
    tape.watch(q_particles)

    misfit = 0
    
    # Compute the SVGD kernel matrix and its gradient for each mini-batch of particles
    for j in range(num_batches):
      # Select the current mini-batch of particles
      q_particles_batch = q_particles[j*batch_size:(j+1)*batch_size]
      
      # Compute pairwise distances between the current mini-batch and all particles
      med = np.median(pairwise_distances(q_particles_batch, q_particles))
      h = med**2/np.log(num_particles)  # Set bandwidth parameter h to be med^2 / log(n)

      ## Compute the SVGD kernel matrix and its gradient for the current mini-batch
      with tf.GradientTape() as tape2:
        rbf_kernel = tfp.math.psd_kernels.ExponentiatedQuadratic(length_scale=float(h))
        svgd_kernel_matrix = rbf_kernel.matrix(q_particles_batch, q_particles)
        grads_kernal_matrix = tape2.gradient(svgd_kernel_matrix, q_particles_batch)

      # Compute the log(d_obs|v) log-likelihood and its gradient for the current mini-batch
      grads_log_prob = compute_parallel(q_particles_batch, num_processes=8)
      log_likelihoods = [J(f(q_particle.numpy()),d_obs,wsrc,zxsrc,zxrec,at,az,ax,next,device) for q_particle in q_particles_batch]
      
      # Compute the SVGD update for the current mini-batch
      update_svgd = (tf.matmul(svgd_kernel_matrix, grads_log_prob) + grads_k

# %%
vmin, vmax = f(u_ref).min(), f(u_ref).max()
plt.imshow(f(q_mean.numpy()).reshape((nz,nx)),vmin=vmin, vmax=vmax)

# %%
plt.imshow(tf.reshape(tfp.stats.stddev(q_particles),[nz,nx]),cmap='Reds')
plt.colorbar()

# %%
plt.plot(misfit_history, label='J')
plt.title("Training history", fontsize=16)
plt.legend()
plt.show()

# %%
# Define the TensorFlow variables for the variational posterior particles
num_particles = 100
q_particles_init = tf.random.normal(shape=(num_particles, nz*nx), dtype=tf.float32)
q_particles = tf.Variable(q_particles_init, dtype=tf.float32)

## Compute the SVGD kernel matrix and its gradient
rbf_kernel = tfp.math.psd_kernels.ExponentiatedQuadratic(length_scale=1.0)
svgd_kernel_matrix = rbf_kernel.matrix(q_particles, q_particles)

# Add a small jitter term to make the matrix numerically stable
jitter = 1e-6
num_particles = 100
svgd_kernel_matrix += jitter * tf.eye(num_particles)

tf.linalg.cholesky(svgd_kernel_matrix)

# %%
# Exapmle code
for i in range(num_iters):
  # Print the iteration number
  print(f"Iteration {i + 1}/{num_iters}")
  
  with tf.GradientTape() as tape:
    # Watch the parameters of the variational posterior
    tape.watch(q_particles)
    
    # Compute the SVGD kernel matrix and its gradient
    q_gradients = tape.gradient(q_particles, q_particles)
    # svgd_kernel_matrix = svgd_kernel(q_particles, q_gradients)
    rbf_kernel = tfp.math.psd_kernels.RBF(length_scale=1.0)
    svgd_kernel_matrix = rbf_kernel.matrix(q_particles, q_particles)
    grads_svgd_kernel_matrix = tape.gradient(svgd_kernel_matrix, q_particles)

    # Compute the log(d_obs|v) log-likelihood and its gradient
    log_likelihoods = []
    grads_log_likelihoods = []
        
    # Compute the gradient of u with respect to the particles
    with tf.GradientTape() as tape2:
      tape2.watch(q_particles)
      u_samples = q_particles
      du_dq = tape2.gradient(u_samples, q_particles)
    
    # Calculate the gradient of the log-likelihoods
    for u in u_samples:
      log_likelihoods.append(loglik_fn(u.numpy(), d_obs, *args))
      grads_log_likelihoods.append(dloglik_du_fn(u.numpy(), d_obs, *args))
    
    # Compute E[log likelihood] and its gradient
    E_log_likelihoods = tf.cast(tf.reduce_mean(log_likelihoods), dtype=tf.float32)
    grads_E_log_likelihoods = tf.cast(tf.reduce_mean(grads_log_likelihoods, axis=0) * du_dq, dtype=tf.float32)

    # Compute the KL(q||p) term 
    kl_divergence_q_p = tfp.distributions.kl_divergence(
        tfp.distributions.MultivariateNormalDiag(loc=q_particles, scale_diag=q_scale), p_dist)
    grads_kl_divergence_q_p = tape.gradient(kl_divergence_q_p, q_particles)
